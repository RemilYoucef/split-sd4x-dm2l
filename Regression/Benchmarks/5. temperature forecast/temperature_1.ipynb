# %%
" Import the libraries " 

import os
import sys 
import math
import copy

import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
" Import the scripts of SD for Explaining "

absFilePath = os.path.dirname(os.path.dirname(os.getcwd()))
newPath = os.path.join(absFilePath, 'SplitSD4X')
sys.path.append(newPath)

from fill_missing_values import *
from missing_values_table import *
from neighbors_generation import *
from patterns_extraction import *
from performances import *
from subgroups_discovery import *
from sp_lime import *

# %% [markdown]
# ## Data Preparation

# %%
" Loading the dataset "
datasets_path = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), 'Datasets\\')
url = datasets_path + 'data_temp_forecast.csv'
df = pd.read_csv(url)

" Handling some data "
df = df.drop(columns=['station','Date'])
df = df.dropna()
df.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          28.7          21.4    58.255688    91.116364         28.074101
# 1          31.9          21.6    52.263397    90.604721         29.850689
# 2          31.6          23.3    48.690479    83.973587         30.091292
# 3          32.0          23.4    58.239788    96.483688         29.704629
# 4          31.4          21.9    56.174095    90.155128         29.113934
#
#    LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.006936  6.818887   69.451805   0.233947   0.203896  ...
# 1         24.035009  5.691890   51.937448   0.225508   0.251771  ...
# 2         24.565633  6.138224   20.573050   0.209344   0.257469  ...
# 3         23.326177  5.650050   65.727144   0.216372   0.226002  ...
# 4         23.486480  5.735004  107.965535   0.151407   0.249995  ...
#
#    LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 23 columns]

# %%
df.dtypes
# Out:
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
df.replace('?', np.nan, inplace=True)
missing_values_table(df)
# Out:
# Your slelected dataframe has 23 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
data_df = df.drop(columns=['Next_Tmax','Next_Tmin'])
target_df = df['Next_Tmax']

# %%
categorical_feature_mask = (data_df.dtypes == object)
categorical_feature_mask
# Out:
# Present_Tmax        False
# Present_Tmin        False
# LDAPS_RHmin         False
# LDAPS_RHmax         False
# LDAPS_Tmax_lapse    False
# LDAPS_Tmin_lapse    False
# LDAPS_WS            False
# LDAPS_LH            False
# LDAPS_CC1           False
# LDAPS_CC2           False
# LDAPS_CC3           False
# LDAPS_CC4           False
# LDAPS_PPT1          False
# LDAPS_PPT2          False
# LDAPS_PPT3          False
# LDAPS_PPT4          False
# lat                 False
# lon                 False
# DEM                 False
# Slope               False
# Solar radiation     False
# dtype: bool

# %%
categorical_cols_names = data_df.columns[categorical_feature_mask].tolist()
categorical_cols_names
# Out:
# []

# %%
numerical_cols_names = data_df.columns[~categorical_feature_mask].tolist()
numerical_cols_names
# Out:
# ['Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation']

# %%
data_df = pd.concat([data_df[numerical_cols_names].astype(float), data_df[categorical_cols_names]],axis = 1)
data_target_df = pd.concat([data_df, target_df], axis=1)

# %%
" generate the Test SET "
nb_test_instances = 1000 
test_df = data_target_df.sample(n=nb_test_instances)
data_test_df = test_df.drop(columns=['Next_Tmax'])
target_test_df = test_df['Next_Tmax']

" generate the Training SET "
train_df = pd.concat([data_target_df,test_df]).drop_duplicates(keep=False)
data_train_df = train_df.drop(columns=['Next_Tmax'])
target_train_df = train_df['Next_Tmax']

# %%
" Extract values of the test set to generate the neighbors"

data_test = data_test_df.values
target_test = target_test_df.values

# %%
numerical_cols = np.arange(0,len(numerical_cols_names)) 
categorical_cols = np.arange(len(numerical_cols_names),data_df.shape[1])

# %% [markdown]
# ## Neighbors Generation

# %%
nb_neighbors = 50
list_neigh = generate_all_neighbors(data_test,numerical_cols,categorical_cols,nb_neighbors)

# %%
" store all the neighbors together "
n = np.size(data_test,0)
all_neighbors = list_neigh[0]
for i in range(1,n) :
    all_neighbors = np.concatenate((all_neighbors, list_neigh[i]), axis=0)

# %% [markdown]
# ###  One hot encoding

# %%
df_neigh = pd.DataFrame(data = all_neighbors,columns= numerical_cols_names + categorical_cols_names)
df_neigh[categorical_cols_names] = df_neigh[categorical_cols_names].astype(int,errors='ignore')
df_neigh.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0     23.920973     17.219490    39.498749    75.987474         25.716597
# 1     23.712622     17.485822    39.631054    76.159475         26.297136
# 2     23.923750     17.376452    37.944531    76.328909         26.285220
# 3     23.877884     17.487214    39.723517    76.384980         26.538964
# 4     24.114361     17.379955    39.276373    75.534605         26.350988
#
#    LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         15.482582  11.649685  138.461254   0.061250   0.041374  ...
# 1         15.765924  11.835588  139.496087   0.002910   0.019792  ...
# 2         15.601202  11.667421  138.019221  -0.011973   0.001624  ...
# 3         15.880048  11.826471  142.770519   0.037470   0.014340  ...
# 4         15.786941  11.804712  139.590620   0.022244   0.003388  ...
#
#    LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4        lat  \
# 0   0.412827    0.253449    0.130638    0.046574   -0.086291  37.607566
# 1   0.406840    0.086534   -0.012401    0.058849    0.256254  37.614574
# 2   0.408866    0.100680   -0.105260    0.048015   -0.078001  37.610500
# 3   0.400041    0.064649   -0.036073    0.018204   -0.278140  37.599801
# 4   0.441470    0.140150   -0.037919    0.007945    0.024942  37.594192
#
#           lon         DEM     Slope  Solar radiation
# 0  126.987934  210.397208  2.779390      4633.977883
# 1  127.010764  219.402128  2.922810      4694.121591
# 2  126.989913  212.736347  2.883223      4678.961408
# 3  126.993946  211.848031  2.765221      4705.963567
# 4  126.973929  199.419125  2.597796      4723.425476
#
# [5 rows x 21 columns]

# %%
" Store the neighbors in a list "
data_neigh = df_neigh.values
n = np.size(data_test,0)
list_neigh = []
j = 0
for i in range(0,n):
    list_neigh.append(data_neigh[j:(j+nb_neighbors),:])
    j += nb_neighbors

# %% [markdown]
# ####  One hot encoding for the training and the test sets

# %%
data_train = data_train_df.values
target_train = target_train_df.values

# %%
data_test = data_test_df.values
target_test = target_test_df.values

# %%
" Define the functions to save and load data "
import pickle
def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
'SAVE THE DATA'

path = './saved_data/'
save_obj(data_train, path + 'data_train')
save_obj(target_train, path + 'target_train')
save_obj(data_test, path  + 'data_test')
save_obj(target_test, path + 'target_test')
save_obj(list_neigh, path + 'list_neighbors')

# %% [markdown]
# ## Training the models

# %%
" Linear Regression : "
regression = LinearRegression()
model_reg = regression.fit(data_train, target_train)
target_pred_reg = model_reg.predict(data_test)

# %%
" Random Forest Regressor "
regr = RandomForestRegressor(n_estimators=500,max_depth=10, random_state=0)
model_rf = regr.fit(data_train, target_train)
target_pred_rf = model_rf.predict(data_test)

# %%
" Ada Boost regressor "
adaBoostRegr = AdaBoostRegressor(random_state=0, n_estimators=200)
model_abr = adaBoostRegr.fit(data_train, target_train)
target_pred_abr = model_abr.predict(data_test)

# %%
" Sklearn MLP regressor "

mlp = make_pipeline(StandardScaler(),
                    MLPRegressor(hidden_layer_sizes=(500,500),
                                 tol=1e-2, 
                                 max_iter=1000, 
                                 random_state=0))
model_nt = mlp.fit(data_train, target_train)
target_pred_nt = model_nt.predict(data_test)
print(f"{'The score of the Multi-Layer-Perceptron Regressor model is ':<60}{': {}'.format(round(model_nt.score(data_test, target_test),4))}")
# Out:
# The score of the Multi-Layer-Perceptron Regressor model is  : 0.9003

# %% [markdown]
# ## Scores of the black box models

# %%
print(f"{'The score of the linear regression model is ' :<60}{': {}'.format(round(model_reg.score(data_test, target_test),4))}")
print(f"{'The score of the Random Forest Regressor model is ':<60}{': {}'.format(round(model_rf.score(data_test, target_test),4))}")
print(f"{'The score of the AdaBoost Regressor model is ':<60}{': {}'.format(round(model_abr.score(data_test, target_test),4))}")
print(f"{'The score of the Multi-Layer-Perceptron Regressor model is ':<60}{': {}'.format(round(model_nt.score(data_test, target_test),4))}")
# Out:
# The score of the linear regression model is                 : 0.7884
# The score of the Random Forest Regressor model is           : 0.8891
# The score of the AdaBoost Regressor model is                : 0.7738
# The score of the Multi-Layer-Perceptron Regressor model is  : 0.9003

# %% [markdown]
# ## Execution of Split Based Selection Form Algorithm :

# %%
split_point = len(numerical_cols)
nb_models = 100
(L_Subgroups,P) = SplitBasedSelectionForm (data_test, target_test, nb_models, model_nt, list_neigh,split_point)

# %%
'SAVE THE LIST OF THE SUBGROUPS'
save_obj(L_Subgroups, path + 'list_subgroups')

# %% [markdown]
# ## Subgroups Descriptions

# %%
att_names = data_test_df.columns
patt_descriptions = patterns(P,split_point,data_test,att_names)
# Out:
# subrgoup 0
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.18 < LDAPS_CC3 <= 0.46
# 83.56 < LDAPS_RHmax <= 100.0
# 37.46 < lat <= 37.57
# 20.28 < LDAPS_Tmax_lapse <= 29.84
# -------------------------------------------------------------------
# subrgoup 1
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.53 < LDAPS_CC4 <= 0.96
# 20.3 < Present_Tmax <= 25.5
# -------------------------------------------------------------------
# subrgoup 2
# 0.0 < LDAPS_CC2 <= 0.58
# 5229.8 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.3 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 3
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 80.91 < LDAPS_RHmax <= 83.56
# 14.27 < LDAPS_Tmin_lapse <= 23.47
# -------------------------------------------------------------------
# subrgoup 4
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.0 < LDAPS_CC4 <= 0.3
# 33.35 < LDAPS_Tmax_lapse <= 37.21
# 127.05 < lon <= 127.14
# -------------------------------------------------------------------
# subrgoup 5
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5043.34
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 30.86 < LDAPS_Tmax_lapse <= 37.21
# 126.83 < lon <= 127.01
# -------------------------------------------------------------------
# subrgoup 6
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.46 < LDAPS_CC3 <= 0.98
# 22.04 < LDAPS_Tmin_lapse <= 23.23
# -------------------------------------------------------------------
# subrgoup 7
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC3 <= 0.35
# 126.83 < lon <= 126.95
# 6.77 < LDAPS_LH <= 87.69
# -------------------------------------------------------------------
# subrgoup 8
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 83.56 < LDAPS_RHmax <= 100.0
# 37.61 < lat <= 37.65
# 29.77 < Present_Tmax <= 36.5
# -------------------------------------------------------------------
# subrgoup 9
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 83.56 < LDAPS_RHmax <= 100.0
# 37.57 < lat <= 37.61
# 29.77 < Present_Tmax <= 36.5
# -------------------------------------------------------------------
# subrgoup 10
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.35 < LDAPS_CC3 <= 0.98
# 0.4 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 11
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 83.56 < LDAPS_RHmax <= 100.0
# 37.57 < lat <= 37.65
# 20.3 < Present_Tmax <= 29.77
# 84.57 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 12
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 83.56 < LDAPS_RHmax <= 100.0
# 37.57 < lat <= 37.65
# 20.3 < Present_Tmax <= 29.77
# 6.77 < LDAPS_LH <= 84.57
# -------------------------------------------------------------------
# subrgoup 13
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.1 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 52.99 < LDAPS_RHmin <= 95.11
# 0.44 < LDAPS_CC1 <= 0.93
# -------------------------------------------------------------------
# subrgoup 14
# 0.0 < LDAPS_CC2 <= 0.58
# 5779.52 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 58.94 < LDAPS_RHmax <= 83.56
# 23.47 < LDAPS_Tmin_lapse <= 28.97
# -------------------------------------------------------------------
# subrgoup 15
# 0.58 < LDAPS_CC2 <= 0.96
# 0.2 < LDAPS_PPT2 <= 2.16
# 78.33 < LDAPS_RHmin <= 95.11
# 93.82 < LDAPS_RHmax <= 100.0
# -------------------------------------------------------------------
# subrgoup 16
# 0.58 < LDAPS_CC2 <= 0.96
# 0.2 < LDAPS_PPT2 <= 2.16
# 67.51 < LDAPS_RHmin <= 78.33
# 93.82 < LDAPS_RHmax <= 100.0
# -------------------------------------------------------------------
# subrgoup 17
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 24.24 < LDAPS_RHmin <= 52.99
# 20.3 < Present_Tmax <= 30.09
# 88.59 < LDAPS_RHmax <= 100.0
# 126.83 < lon <= 126.98
# -------------------------------------------------------------------
# subrgoup 18
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC3 <= 0.35
# 126.95 < lon <= 127.14
# 0.29 < LDAPS_CC1 <= 0.93
# 0.14 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 19
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC3 <= 0.35
# 126.95 < lon <= 127.14
# 0.29 < LDAPS_CC1 <= 0.93
# 0.0 < LDAPS_CC4 <= 0.14
# -------------------------------------------------------------------
# subrgoup 20
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 0.2
# 67.51 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC1 <= 0.41
# 37.55 < lat <= 37.65
# -------------------------------------------------------------------
# subrgoup 21
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 0.2
# 67.51 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC1 <= 0.41
# 37.46 < lat <= 37.55
# -------------------------------------------------------------------
# subrgoup 22
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.14 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 24.24 < LDAPS_RHmin <= 52.99
# 30.09 < Present_Tmax <= 36.5
# -------------------------------------------------------------------
# subrgoup 23
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.14
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 24.24 < LDAPS_RHmin <= 52.99
# 30.09 < Present_Tmax <= 36.5
# -------------------------------------------------------------------
# subrgoup 24
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.53 < LDAPS_CC4 <= 0.96
# 25.5 < Present_Tmax <= 36.5
# 58.0 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 25
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.53 < LDAPS_CC4 <= 0.96
# 25.5 < Present_Tmax <= 36.5
# 6.77 < LDAPS_LH <= 58.0
# -------------------------------------------------------------------
# subrgoup 26
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.0 < LDAPS_CC4 <= 0.3
# 20.28 < LDAPS_Tmax_lapse <= 33.35
# 6.1 < LDAPS_WS <= 16.43
# -------------------------------------------------------------------
# subrgoup 27
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.0 < LDAPS_CC4 <= 0.3
# 20.28 < LDAPS_Tmax_lapse <= 33.35
# 3.51 < LDAPS_WS <= 6.1
# -------------------------------------------------------------------
# subrgoup 28
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.15 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 24.24 < LDAPS_RHmin <= 52.99
# 20.3 < Present_Tmax <= 30.09
# 58.94 < LDAPS_RHmax <= 88.59
# -------------------------------------------------------------------
# subrgoup 29
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.15
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 24.24 < LDAPS_RHmin <= 52.99
# 20.3 < Present_Tmax <= 30.09
# 58.94 < LDAPS_RHmax <= 88.59
# -------------------------------------------------------------------
# subrgoup 30
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.78 < LDAPS_CC1 <= 0.93
# 2.24 < LDAPS_PPT1 <= 20.94
# 0.7 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 31
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.78 < LDAPS_CC1 <= 0.93
# 2.24 < LDAPS_PPT1 <= 20.94
# 0.0 < LDAPS_CC4 <= 0.7
# -------------------------------------------------------------------
# subrgoup 32
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.18
# 83.56 < LDAPS_RHmax <= 100.0
# 37.46 < lat <= 37.57
# 20.28 < LDAPS_Tmax_lapse <= 29.23
# 7.72 < LDAPS_WS <= 16.43
# -------------------------------------------------------------------
# subrgoup 33
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.18
# 83.56 < LDAPS_RHmax <= 100.0
# 37.46 < lat <= 37.57
# 20.28 < LDAPS_Tmax_lapse <= 29.23
# 3.51 < LDAPS_WS <= 7.72
# -------------------------------------------------------------------
# subrgoup 34
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 4851.32
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 52.99 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC1 <= 0.44
# -------------------------------------------------------------------
# subrgoup 35
# 0.05 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.0 < LDAPS_CC4 <= 0.3
# 33.35 < LDAPS_Tmax_lapse <= 37.21
# 126.83 < lon <= 127.05
# -------------------------------------------------------------------
# subrgoup 36
# 0.0 < LDAPS_CC2 <= 0.05
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.0 < LDAPS_CC4 <= 0.3
# 33.35 < LDAPS_Tmax_lapse <= 37.21
# 126.83 < lon <= 127.05
# -------------------------------------------------------------------
# subrgoup 37
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.18
# 83.56 < LDAPS_RHmax <= 100.0
# 37.46 < lat <= 37.57
# 29.23 < LDAPS_Tmax_lapse <= 37.21
# 34.88 < DEM <= 212.34
# -------------------------------------------------------------------
# subrgoup 38
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.18
# 83.56 < LDAPS_RHmax <= 100.0
# 37.46 < lat <= 37.57
# 29.23 < LDAPS_Tmax_lapse <= 37.21
# 12.37 < DEM <= 34.88
# -------------------------------------------------------------------
# subrgoup 39
# 0.58 < LDAPS_CC2 <= 0.96
# 0.2 < LDAPS_PPT2 <= 2.16
# 67.51 < LDAPS_RHmin <= 95.11
# 58.94 < LDAPS_RHmax <= 93.82
# 4371.68 < Solar radiation <= 4940.22
# -------------------------------------------------------------------
# subrgoup 40
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 11.3 < Present_Tmin <= 23.75
# 26.66 < LDAPS_Tmax_lapse <= 37.21
# 5190.96 < Solar radiation <= 5968.81
# -------------------------------------------------------------------
# subrgoup 41
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 11.3 < Present_Tmin <= 23.75
# 26.66 < LDAPS_Tmax_lapse <= 37.21
# 4371.68 < Solar radiation <= 5190.96
# -------------------------------------------------------------------
# subrgoup 42
# 0.0 < LDAPS_CC2 <= 0.58
# 5043.34 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 31.44 < LDAPS_Tmax_lapse <= 37.21
# 126.83 < lon <= 127.01
# -------------------------------------------------------------------
# subrgoup 43
# 0.0 < LDAPS_CC2 <= 0.58
# 5043.34 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 30.86 < LDAPS_Tmax_lapse <= 31.44
# 126.83 < lon <= 127.01
# -------------------------------------------------------------------
# subrgoup 44
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.78 < LDAPS_CC1 <= 0.93
# 0.0 < LDAPS_PPT1 <= 2.24
# 0.77 < LDAPS_CC3 <= 0.98
# -------------------------------------------------------------------
# subrgoup 45
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.78 < LDAPS_CC1 <= 0.93
# 0.0 < LDAPS_PPT1 <= 2.24
# 0.0 < LDAPS_CC3 <= 0.77
# -------------------------------------------------------------------
# subrgoup 46
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.46 < LDAPS_CC3 <= 0.98
# 23.23 < LDAPS_Tmin_lapse <= 28.97
# 29.74 < Present_Tmax <= 36.5
# 0.49 < LDAPS_CC1 <= 0.93
# -------------------------------------------------------------------
# subrgoup 47
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.46 < LDAPS_CC3 <= 0.98
# 23.23 < LDAPS_Tmin_lapse <= 28.97
# 29.74 < Present_Tmax <= 36.5
# 0.0 < LDAPS_CC1 <= 0.49
# -------------------------------------------------------------------
# subrgoup 48
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.46 < LDAPS_CC3 <= 0.98
# 23.23 < LDAPS_Tmin_lapse <= 28.97
# 20.3 < Present_Tmax <= 29.74
# 42.31 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 49
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.46 < LDAPS_CC3 <= 0.98
# 23.23 < LDAPS_Tmin_lapse <= 28.97
# 20.3 < Present_Tmax <= 29.74
# 6.77 < LDAPS_LH <= 42.31
# -------------------------------------------------------------------
# subrgoup 50
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 30.86 < LDAPS_Tmax_lapse <= 37.21
# 127.01 < lon <= 127.14
# 12.37 < DEM <= 29.54
# 87.15 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 51
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 30.86 < LDAPS_Tmax_lapse <= 37.21
# 127.01 < lon <= 127.14
# 12.37 < DEM <= 29.54
# 6.77 < LDAPS_LH <= 87.15
# -------------------------------------------------------------------
# subrgoup 52
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 58.94 < LDAPS_RHmax <= 80.91
# 14.27 < LDAPS_Tmin_lapse <= 23.47
# 1.73 < Slope <= 5.18
# -------------------------------------------------------------------
# subrgoup 53
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC3 <= 0.46
# 58.94 < LDAPS_RHmax <= 80.91
# 14.27 < LDAPS_Tmin_lapse <= 23.47
# 0.1 < Slope <= 1.73
# -------------------------------------------------------------------
# subrgoup 54
# 0.0 < LDAPS_CC2 <= 0.58
# 4804.37 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.59 < lat <= 37.65
# 0.0 < LDAPS_CC4 <= 0.16
# 24.24 < LDAPS_RHmin <= 53.6
# -------------------------------------------------------------------
# subrgoup 55
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 4804.37
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.59 < lat <= 37.65
# 0.0 < LDAPS_CC4 <= 0.16
# 24.24 < LDAPS_RHmin <= 53.6
# -------------------------------------------------------------------
# subrgoup 56
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 23.75 < Present_Tmin <= 28.9
# 20.3 < Present_Tmax <= 30.0
# 0.68 < LDAPS_CC1 <= 0.93
# -------------------------------------------------------------------
# subrgoup 57
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 23.75 < Present_Tmin <= 28.9
# 20.3 < Present_Tmax <= 30.0
# 0.0 < LDAPS_CC1 <= 0.68
# -------------------------------------------------------------------
# subrgoup 58
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 23.75 < Present_Tmin <= 28.9
# 30.0 < Present_Tmax <= 36.5
# 0.54 < LDAPS_CC3 <= 0.98
# -------------------------------------------------------------------
# subrgoup 59
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 23.75 < Present_Tmin <= 28.9
# 30.0 < Present_Tmax <= 36.5
# 0.0 < LDAPS_CC3 <= 0.54
# -------------------------------------------------------------------
# subrgoup 60
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 22.17
# 37.59 < lat <= 37.65
# 0.16 < LDAPS_CC4 <= 0.96
# 85.04 < LDAPS_RHmax <= 100.0
# -------------------------------------------------------------------
# subrgoup 61
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 22.17
# 37.59 < lat <= 37.65
# 0.16 < LDAPS_CC4 <= 0.96
# 58.94 < LDAPS_RHmax <= 85.04
# -------------------------------------------------------------------
# subrgoup 62
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 11.3 < Present_Tmin <= 23.75
# 26.02 < LDAPS_Tmax_lapse <= 26.66
# -------------------------------------------------------------------
# subrgoup 63
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 2.16
# 24.24 < LDAPS_RHmin <= 67.51
# 11.3 < Present_Tmin <= 23.75
# 20.28 < LDAPS_Tmax_lapse <= 26.02
# -------------------------------------------------------------------
# subrgoup 64
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.18 < LDAPS_CC3 <= 0.46
# 83.56 < LDAPS_RHmax <= 100.0
# 37.46 < lat <= 37.57
# 29.84 < LDAPS_Tmax_lapse <= 37.21
# 0.19 < LDAPS_CC1 <= 0.93
# -------------------------------------------------------------------
# subrgoup 65
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.18 < LDAPS_CC3 <= 0.46
# 83.56 < LDAPS_RHmax <= 100.0
# 37.46 < lat <= 37.57
# 29.84 < LDAPS_Tmax_lapse <= 37.21
# 0.0 < LDAPS_CC1 <= 0.19
# -------------------------------------------------------------------
# subrgoup 66
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 30.86 < LDAPS_Tmax_lapse <= 37.21
# 127.01 < lon <= 127.14
# 29.54 < DEM <= 212.34
# 1.42 < Slope <= 5.18
# -------------------------------------------------------------------
# subrgoup 67
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 30.86 < LDAPS_Tmax_lapse <= 37.21
# 127.01 < lon <= 127.14
# 29.54 < DEM <= 212.34
# 0.1 < Slope <= 1.42
# -------------------------------------------------------------------
# subrgoup 68
# 0.0 < LDAPS_CC2 <= 0.58
# 4874.6 < Solar radiation <= 5229.8
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.3 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 69
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 4874.6
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 24.24 < LDAPS_RHmin <= 51.37
# 0.3 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 70
# 0.3 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 22.17 < LDAPS_Tmin_lapse <= 25.02
# 37.59 < lat <= 37.65
# 0.16 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 71
# 0.0 < LDAPS_CC2 <= 0.3
# 4371.68 < Solar radiation <= 5649.38
# 22.17 < LDAPS_Tmin_lapse <= 25.02
# 37.59 < lat <= 37.65
# 0.16 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 72
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.46 < LDAPS_CC3 <= 0.98
# 14.27 < LDAPS_Tmin_lapse <= 22.04
# 0.66 < LDAPS_PPT3 <= 8.5
# -------------------------------------------------------------------
# subrgoup 73
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5968.81
# 0.46 < LDAPS_CC3 <= 0.98
# 14.27 < LDAPS_Tmin_lapse <= 22.04
# 0.0 < LDAPS_PPT3 <= 0.66
# -------------------------------------------------------------------
# subrgoup 74
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.1
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 52.99 < LDAPS_RHmin <= 95.11
# 0.44 < LDAPS_CC1 <= 0.93
# 0.61 < Slope <= 5.18
# -------------------------------------------------------------------
# subrgoup 75
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.1
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 52.99 < LDAPS_RHmin <= 95.11
# 0.44 < LDAPS_CC1 <= 0.93
# 0.1 < Slope <= 0.61
# -------------------------------------------------------------------
# subrgoup 76
# 0.58 < LDAPS_CC2 <= 0.96
# 0.04 < LDAPS_PPT2 <= 0.2
# 67.51 < LDAPS_RHmin <= 95.11
# 0.41 < LDAPS_CC1 <= 0.93
# 91.96 < LDAPS_RHmax <= 100.0
# -------------------------------------------------------------------
# subrgoup 77
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 0.04
# 67.51 < LDAPS_RHmin <= 95.11
# 0.41 < LDAPS_CC1 <= 0.93
# 91.96 < LDAPS_RHmax <= 100.0
# -------------------------------------------------------------------
# subrgoup 78
# 0.0 < LDAPS_CC2 <= 0.58
# 5127.85 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC3 <= 0.35
# 126.95 < lon <= 127.14
# 0.0 < LDAPS_CC1 <= 0.29
# -------------------------------------------------------------------
# subrgoup 79
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5127.85
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC3 <= 0.35
# 126.95 < lon <= 127.14
# 0.0 < LDAPS_CC1 <= 0.29
# -------------------------------------------------------------------
# subrgoup 80
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.61 < lat <= 37.65
# 0.0 < LDAPS_CC4 <= 0.16
# 53.6 < LDAPS_RHmin <= 95.11
# -------------------------------------------------------------------
# subrgoup 81
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.59 < lat <= 37.61
# 0.0 < LDAPS_CC4 <= 0.16
# 53.6 < LDAPS_RHmin <= 95.11
# -------------------------------------------------------------------
# subrgoup 82
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.4 < LDAPS_CC3 <= 0.98
# 0.0 < LDAPS_CC4 <= 0.4
# -------------------------------------------------------------------
# subrgoup 83
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.35 < LDAPS_CC3 <= 0.4
# 0.0 < LDAPS_CC4 <= 0.4
# -------------------------------------------------------------------
# subrgoup 84
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.0 < LDAPS_CC1 <= 0.78
# 29.72 < Present_Tmax <= 36.5
# 50.45 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 85
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.0 < LDAPS_CC1 <= 0.78
# 29.72 < Present_Tmax <= 36.5
# 6.77 < LDAPS_LH <= 50.45
# -------------------------------------------------------------------
# subrgoup 86
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5779.52
# 0.0 < LDAPS_CC3 <= 0.46
# 58.94 < LDAPS_RHmax <= 83.56
# 23.47 < LDAPS_Tmin_lapse <= 28.97
# 0.15 < LDAPS_CC1 <= 0.93
# -------------------------------------------------------------------
# subrgoup 87
# 0.0 < LDAPS_CC2 <= 0.58
# 5649.38 < Solar radiation <= 5779.52
# 0.0 < LDAPS_CC3 <= 0.46
# 58.94 < LDAPS_RHmax <= 83.56
# 23.47 < LDAPS_Tmin_lapse <= 28.97
# 0.0 < LDAPS_CC1 <= 0.15
# -------------------------------------------------------------------
# subrgoup 88
# 0.0 < LDAPS_CC2 <= 0.58
# 4851.32 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 61.05 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC1 <= 0.44
# -------------------------------------------------------------------
# subrgoup 89
# 0.0 < LDAPS_CC2 <= 0.58
# 4851.32 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 52.99 < LDAPS_RHmin <= 61.05
# 0.0 < LDAPS_CC1 <= 0.44
# -------------------------------------------------------------------
# subrgoup 90
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 0.2
# 67.51 < LDAPS_RHmin <= 95.11
# 0.41 < LDAPS_CC1 <= 0.93
# 58.94 < LDAPS_RHmax <= 91.96
# 0.65 < LDAPS_PPT1 <= 20.94
# -------------------------------------------------------------------
# subrgoup 91
# 0.58 < LDAPS_CC2 <= 0.96
# 0.0 < LDAPS_PPT2 <= 0.2
# 67.51 < LDAPS_RHmin <= 95.11
# 0.41 < LDAPS_CC1 <= 0.93
# 58.94 < LDAPS_RHmax <= 91.96
# 0.0 < LDAPS_PPT1 <= 0.65
# -------------------------------------------------------------------
# subrgoup 92
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.0 < LDAPS_CC1 <= 0.78
# 20.3 < Present_Tmax <= 29.72
# 0.07 < LDAPS_PPT4 <= 14.78
# -------------------------------------------------------------------
# subrgoup 93
# 0.58 < LDAPS_CC2 <= 0.96
# 2.16 < LDAPS_PPT2 <= 21.62
# 0.0 < LDAPS_CC1 <= 0.78
# 20.3 < Present_Tmax <= 29.72
# 0.0 < LDAPS_PPT4 <= 0.07
# -------------------------------------------------------------------
# subrgoup 94
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 24.24 < LDAPS_RHmin <= 52.99
# 20.3 < Present_Tmax <= 30.09
# 88.59 < LDAPS_RHmax <= 100.0
# 126.98 < lon <= 127.14
# 79.03 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 95
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 14.27 < LDAPS_Tmin_lapse <= 25.02
# 37.46 < lat <= 37.59
# 0.0 < LDAPS_CC4 <= 0.53
# 20.28 < LDAPS_Tmax_lapse <= 30.86
# 24.24 < LDAPS_RHmin <= 52.99
# 20.3 < Present_Tmax <= 30.09
# 88.59 < LDAPS_RHmax <= 100.0
# 126.98 < lon <= 127.14
# 6.77 < LDAPS_LH <= 79.03
# -------------------------------------------------------------------
# subrgoup 96
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.27 < LDAPS_CC3 <= 0.35
# 126.83 < lon <= 126.95
# 87.69 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 97
# 0.0 < LDAPS_CC2 <= 0.58
# 4371.68 < Solar radiation <= 5649.38
# 25.02 < LDAPS_Tmin_lapse <= 28.97
# 51.37 < LDAPS_RHmin <= 95.11
# 0.0 < LDAPS_CC3 <= 0.27
# 126.83 < lon <= 126.95
# 87.69 < LDAPS_LH <= 200.41
# -------------------------------------------------------------------
# subrgoup 98
# 0.58 < LDAPS_CC2 <= 0.96
# 0.2 < LDAPS_PPT2 <= 2.16
# 67.51 < LDAPS_RHmin <= 95.11
# 58.94 < LDAPS_RHmax <= 93.82
# 4940.22 < Solar radiation <= 5968.81
# 0.75 < LDAPS_CC4 <= 0.96
# -------------------------------------------------------------------
# subrgoup 99
# 0.58 < LDAPS_CC2 <= 0.96
# 0.2 < LDAPS_PPT2 <= 2.16
# 67.51 < LDAPS_RHmin <= 95.11
# 58.94 < LDAPS_RHmax <= 93.82
# 4940.22 < Solar radiation <= 5968.81
# 0.0 < LDAPS_CC4 <= 0.75
# -------------------------------------------------------------------

# %%
'SAVE THE SUBGROUPS PATTERNS'
save_obj(patt_descriptions, path + 'patterns')
save_obj(att_names, path + 'att_names')
