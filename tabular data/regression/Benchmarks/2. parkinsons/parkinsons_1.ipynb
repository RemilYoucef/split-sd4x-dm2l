# %%
" Import the libraries " 

import os
import sys 
import math
import copy

import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
" Import the scripts of SD for Explaining "

absFilePath = os.path.dirname(os.path.dirname(os.getcwd()))
newPath = os.path.join(absFilePath, 'SplitSD4X')
sys.path.append(newPath)

from fill_missing_values import *
from missing_values_table import *
from neighbors_generation import *
from patterns_extraction import *
from performances import *
from subgroups_discovery import *
from sp_lime import *

# %% [markdown]
# ## Data Preparation

# %%
" Loading the dataset "
datasets_path = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), 'Datasets\\')
url = datasets_path + 'data_parkinsons_updrs.csv'
df = pd.read_csv(url)
df = df.drop(['subject#','motor_UPDRS'],axis =1)
df.head()
# Out:
#    age  sex  test_time  total_UPDRS  Jitter(%)  Jitter(Abs)  Jitter:RAP  \
# 0   72    0     5.6431       34.398    0.00662     0.000034     0.00401
# 1   72    0    12.6660       34.894    0.00300     0.000017     0.00132
# 2   72    0    19.6810       35.389    0.00481     0.000025     0.00205
# 3   72    0    25.6470       35.810    0.00528     0.000027     0.00191
# 4   72    0    33.6420       36.375    0.00335     0.000020     0.00093
#
#    Jitter:PPQ5  Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0      0.00317     0.01204  0.02565        0.230       0.01438       0.01309
# 1      0.00150     0.00395  0.02024        0.179       0.00994       0.01072
# 2      0.00208     0.00616  0.01675        0.181       0.00734       0.00844
# 3      0.00264     0.00573  0.02309        0.327       0.01106       0.01265
# 4      0.00130     0.00278  0.01703        0.176       0.00679       0.00929
#
#    Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE
# 0        0.01662      0.04314  0.014290  21.640  0.41888  0.54842  0.16006
# 1        0.01689      0.02982  0.011112  27.183  0.43493  0.56477  0.10810
# 2        0.01458      0.02202  0.020220  23.047  0.46222  0.54405  0.21014
# 3        0.01963      0.03317  0.027837  24.445  0.48730  0.57794  0.33277
# 4        0.01819      0.02036  0.011625  26.126  0.47188  0.56122  0.19361

# %%
" Decode Categorical Features "

sex_mapper = {0 : 'male', 
              1 : 'female' }
sex_mapper_inv = dict(map(reversed, sex_mapper.items()))
df['sex'] = df['sex'].replace(sex_mapper)
df.head()
# Out:
#    age   sex  test_time  total_UPDRS  Jitter(%)  Jitter(Abs)  Jitter:RAP  \
# 0   72  male     5.6431       34.398    0.00662     0.000034     0.00401
# 1   72  male    12.6660       34.894    0.00300     0.000017     0.00132
# 2   72  male    19.6810       35.389    0.00481     0.000025     0.00205
# 3   72  male    25.6470       35.810    0.00528     0.000027     0.00191
# 4   72  male    33.6420       36.375    0.00335     0.000020     0.00093
#
#    Jitter:PPQ5  Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0      0.00317     0.01204  0.02565        0.230       0.01438       0.01309
# 1      0.00150     0.00395  0.02024        0.179       0.00994       0.01072
# 2      0.00208     0.00616  0.01675        0.181       0.00734       0.00844
# 3      0.00264     0.00573  0.02309        0.327       0.01106       0.01265
# 4      0.00130     0.00278  0.01703        0.176       0.00679       0.00929
#
#    Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE
# 0        0.01662      0.04314  0.014290  21.640  0.41888  0.54842  0.16006
# 1        0.01689      0.02982  0.011112  27.183  0.43493  0.56477  0.10810
# 2        0.01458      0.02202  0.020220  23.047  0.46222  0.54405  0.21014
# 3        0.01963      0.03317  0.027837  24.445  0.48730  0.57794  0.33277
# 4        0.01819      0.02036  0.011625  26.126  0.47188  0.56122  0.19361

# %%
" display the features types "
df.dtypes
# Out:
# age                int64
# sex               object
# test_time        float64
# total_UPDRS      float64
# Jitter(%)        float64
# Jitter(Abs)      float64
# Jitter:RAP       float64
# Jitter:PPQ5      float64
# Jitter:DDP       float64
# Shimmer          float64
# Shimmer(dB)      float64
# Shimmer:APQ3     float64
# Shimmer:APQ5     float64
# Shimmer:APQ11    float64
# Shimmer:DDA      float64
# NHR              float64
# HNR              float64
# RPDE             float64
# DFA              float64
# PPE              float64
# dtype: object

# %%
" Checking missing values "
df.replace('?', np.nan, inplace=True)
missing_values_table(df)
# Out:
# Your slelected dataframe has 20 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
" separate the data and the target "
data_df = df.drop(columns=['total_UPDRS'])
target_df = df['total_UPDRS']

# %%
" calculate the categorical features mask "
categorical_feature_mask = (data_df.dtypes == object)
categorical_feature_mask
# Out:
# age              False
# sex               True
# test_time        False
# Jitter(%)        False
# Jitter(Abs)      False
# Jitter:RAP       False
# Jitter:PPQ5      False
# Jitter:DDP       False
# Shimmer          False
# Shimmer(dB)      False
# Shimmer:APQ3     False
# Shimmer:APQ5     False
# Shimmer:APQ11    False
# Shimmer:DDA      False
# NHR              False
# HNR              False
# RPDE             False
# DFA              False
# PPE              False
# dtype: bool

# %%
categorical_cols_names = data_df.columns[categorical_feature_mask].tolist()
categorical_cols_names
# Out:
# ['sex']

# %%
numerical_cols_names = data_df.columns[~categorical_feature_mask].tolist()
numerical_cols_names
# Out:
# ['age',
#  'test_time',
#  'Jitter(%)',
#  'Jitter(Abs)',
#  'Jitter:RAP',
#  'Jitter:PPQ5',
#  'Jitter:DDP',
#  'Shimmer',
#  'Shimmer(dB)',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'Shimmer:APQ11',
#  'Shimmer:DDA',
#  'NHR',
#  'HNR',
#  'RPDE',
#  'DFA',
#  'PPE']

# %%
" if no values missed we execute this code : "
data_df = pd.concat([data_df[numerical_cols_names], data_df[categorical_cols_names]],axis = 1)
data_df.head()
# Out:
#    age  test_time  Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  \
# 0   72     5.6431    0.00662     0.000034     0.00401      0.00317
# 1   72    12.6660    0.00300     0.000017     0.00132      0.00150
# 2   72    19.6810    0.00481     0.000025     0.00205      0.00208
# 3   72    25.6470    0.00528     0.000027     0.00191      0.00264
# 4   72    33.6420    0.00335     0.000020     0.00093      0.00130
#
#    Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0     0.01204  0.02565        0.230       0.01438       0.01309
# 1     0.00395  0.02024        0.179       0.00994       0.01072
# 2     0.00616  0.01675        0.181       0.00734       0.00844
# 3     0.00573  0.02309        0.327       0.01106       0.01265
# 4     0.00278  0.01703        0.176       0.00679       0.00929
#
#    Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE  \
# 0        0.01662      0.04314  0.014290  21.640  0.41888  0.54842  0.16006
# 1        0.01689      0.02982  0.011112  27.183  0.43493  0.56477  0.10810
# 2        0.01458      0.02202  0.020220  23.047  0.46222  0.54405  0.21014
# 3        0.01963      0.03317  0.027837  24.445  0.48730  0.57794  0.33277
# 4        0.01819      0.02036  0.011625  26.126  0.47188  0.56122  0.19361
#
#     sex
# 0  male
# 1  male
# 2  male
# 3  male
# 4  male

# %%
" Encoding categorical features "
data_df['sex'] = data_df['sex'].replace(sex_mapper_inv)

# %%
data_target_df = pd.concat([data_df, target_df], axis=1)

# %%
" generate the Test SET "
nb_test_instances = 1000 
test_df = data_target_df.sample(n=nb_test_instances)
data_test_df = test_df.drop(columns=['total_UPDRS'])
target_test_df = test_df['total_UPDRS']

# %%
" generate the Training SET "
train_df = pd.concat([data_target_df,test_df]).drop_duplicates(keep=False)
data_train_df = train_df.drop(columns=['total_UPDRS'])
target_train_df = train_df['total_UPDRS']

# %%
" Extract values of the test set to generate the neighbors"

data_test = data_test_df.values
target_test = target_test_df.values

# %%
numerical_cols = np.arange(0,len(numerical_cols_names)) 
categorical_cols = np.arange(len(numerical_cols_names),data_df.shape[1])

# %% [markdown]
# ## Neighbors Generation

# %%
nb_neighbors = 50 
list_neigh = generate_all_neighbors(data_test,numerical_cols,categorical_cols,nb_neighbors)

# %%
" store all the neighbors together "
n = np.size(data_test,0)
all_neighbors = list_neigh[0]
for i in range(1,n) :
    all_neighbors = np.concatenate((all_neighbors, list_neigh[i]), axis=0)

# %% [markdown]
# ###  One hot encoding

# %%
df_neigh = pd.DataFrame(data = all_neighbors,columns= numerical_cols_names + categorical_cols_names)
df_neigh[categorical_cols_names] = df_neigh[categorical_cols_names].astype(int,errors='ignore')

" Decode all the data neighbors to perform one hot encoding "
df_neigh['sex'] = df_neigh['sex'].replace(sex_mapper)
df_neigh.head()
# Out:
#          age   test_time  Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  \
# 0  72.066701   98.659117   0.004072     0.000039    0.001738     0.002366
# 1  70.546883  107.723381   0.004353     0.000039    0.001856     0.002575
# 2  72.326985  102.890964   0.004250     0.000037    0.001771     0.002481
# 3  73.179925   96.703031   0.004530     0.000040    0.001936     0.002684
# 4  71.193294  104.981597   0.003719     0.000035    0.001550     0.002076
#
#    Jitter:DDP   Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0    0.005205  0.024804     0.213100      0.011645      0.015545
# 1    0.005558  0.026597     0.225856      0.012879      0.016913
# 2    0.005302  0.025016     0.219846      0.011968      0.016195
# 3    0.005797  0.028588     0.247328      0.013687      0.018185
# 4    0.004639  0.025502     0.217516      0.012211      0.016200
#
#    Shimmer:APQ11  Shimmer:DDA       NHR        HNR      RPDE       DFA  \
# 0       0.023496     0.034935  0.008132  23.030725  0.549659  0.587949
# 1       0.023853     0.038637  0.013734  22.629600  0.523855  0.586936
# 2       0.023423     0.035904  0.015806  23.183551  0.525600  0.572226
# 3       0.026357     0.041062  0.016496  22.682033  0.535223  0.577245
# 4       0.023964     0.036634  0.007995  22.941752  0.528982  0.584647
#
#         PPE   sex
# 0  0.206242  male
# 1  0.206067  male
# 2  0.197111  male
# 3  0.208496  male
# 4  0.195377  male

# %%
" One hot encoding "
df_neigh = pd.get_dummies(df_neigh, prefix_sep='_', drop_first=True)
df_neigh.head()
# Out:
#          age   test_time  Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  \
# 0  72.066701   98.659117   0.004072     0.000039    0.001738     0.002366
# 1  70.546883  107.723381   0.004353     0.000039    0.001856     0.002575
# 2  72.326985  102.890964   0.004250     0.000037    0.001771     0.002481
# 3  73.179925   96.703031   0.004530     0.000040    0.001936     0.002684
# 4  71.193294  104.981597   0.003719     0.000035    0.001550     0.002076
#
#    Jitter:DDP   Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0    0.005205  0.024804     0.213100      0.011645      0.015545
# 1    0.005558  0.026597     0.225856      0.012879      0.016913
# 2    0.005302  0.025016     0.219846      0.011968      0.016195
# 3    0.005797  0.028588     0.247328      0.013687      0.018185
# 4    0.004639  0.025502     0.217516      0.012211      0.016200
#
#    Shimmer:APQ11  Shimmer:DDA       NHR        HNR      RPDE       DFA  \
# 0       0.023496     0.034935  0.008132  23.030725  0.549659  0.587949
# 1       0.023853     0.038637  0.013734  22.629600  0.523855  0.586936
# 2       0.023423     0.035904  0.015806  23.183551  0.525600  0.572226
# 3       0.026357     0.041062  0.016496  22.682033  0.535223  0.577245
# 4       0.023964     0.036634  0.007995  22.941752  0.528982  0.584647
#
#         PPE  sex_male
# 0  0.206242         1
# 1  0.206067         1
# 2  0.197111         1
# 3  0.208496         1
# 4  0.195377         1

# %%
" Store the neighbors in a list"

data_neigh = df_neigh.values
n = np.size(data_test,0)
list_neigh = []
j = 0
for i in range(0,n):
    list_neigh.append(data_neigh[j:(j+nb_neighbors),:])
    j += nb_neighbors

# %% [markdown]
# ####  One hot encoding for the training and the test sets

# %%
data_train_df['sex'] = data_train_df['sex'].replace(sex_mapper)

# %%
data_train_df = pd.get_dummies(data_train_df, prefix_sep='_', drop_first=True)
data_train_df.head()
# Out:
#    age  test_time  Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  \
# 0   72     5.6431    0.00662     0.000034     0.00401      0.00317
# 1   72    12.6660    0.00300     0.000017     0.00132      0.00150
# 2   72    19.6810    0.00481     0.000025     0.00205      0.00208
# 3   72    25.6470    0.00528     0.000027     0.00191      0.00264
# 4   72    33.6420    0.00335     0.000020     0.00093      0.00130
#
#    Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0     0.01204  0.02565        0.230       0.01438       0.01309
# 1     0.00395  0.02024        0.179       0.00994       0.01072
# 2     0.00616  0.01675        0.181       0.00734       0.00844
# 3     0.00573  0.02309        0.327       0.01106       0.01265
# 4     0.00278  0.01703        0.176       0.00679       0.00929
#
#    Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE  \
# 0        0.01662      0.04314  0.014290  21.640  0.41888  0.54842  0.16006
# 1        0.01689      0.02982  0.011112  27.183  0.43493  0.56477  0.10810
# 2        0.01458      0.02202  0.020220  23.047  0.46222  0.54405  0.21014
# 3        0.01963      0.03317  0.027837  24.445  0.48730  0.57794  0.33277
# 4        0.01819      0.02036  0.011625  26.126  0.47188  0.56122  0.19361
#
#    sex_male
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
data_train = data_train_df.values
target_train = target_train_df.values

# %%
data_test_df['sex'] = data_test_df['sex'].replace(sex_mapper)

# %%
data_test_df = pd.get_dummies(data_test_df, prefix_sep='_', drop_first=True)
data_test_df.head()
# Out:
#       age  test_time  Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  \
# 922    72    105.300    0.00407     0.000037     0.00169      0.00234
# 539    74     79.669    0.00240     0.000018     0.00094      0.00131
# 220    58    166.760    0.00621     0.000045     0.00300      0.00335
# 3507   49     66.851    0.00883     0.000091     0.00511      0.00488
# 3144   59    107.520    0.00322     0.000017     0.00168      0.00172
#
#       Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 922      0.00506  0.02647        0.229       0.01278       0.01702
# 539      0.00283  0.02880        0.247       0.01373       0.01676
# 220      0.00900  0.04671        0.454       0.02602       0.03020
# 3507     0.01534  0.04086        0.362       0.02120       0.02495
# 3144     0.00503  0.01727        0.155       0.00972       0.01011
#
#       Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE  \
# 922         0.02450      0.03834  0.012899  22.759  0.53150  0.57912  0.20233
# 539         0.02476      0.04119  0.011364  22.645  0.70869  0.60409  0.10738
# 220         0.03540      0.07806  0.020905  20.639  0.47387  0.70712  0.17682
# 3507        0.03560      0.06359  0.024856  17.633  0.67118  0.74831  0.34800
# 3144        0.01254      0.02916  0.012371  23.947  0.46907  0.65800  0.14207
#
#       sex_male
# 922          1
# 539          1
# 220          1
# 3507         1
# 3144         0

# %%
data_test = data_test_df.values
target_test = target_test_df.values

# %%
" Define the functions to save and load data "
import pickle
def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
'SAVE THE DATA'

path = './saved_data/'
save_obj(data_train, path + 'data_train')
save_obj(target_train, path + 'target_train')
save_obj(data_test, path  + 'data_test')
save_obj(target_test, path + 'target_test')
save_obj(list_neigh, path + 'list_neighbors')

# %% [markdown]
# ## Training the models

# %%
" Linear Regression : "
regression = LinearRegression()
model_reg = regression.fit(data_train, target_train)
target_pred_reg = model_reg.predict(data_test)

# %%
" Random Forest Regressor "
regr = RandomForestRegressor(n_estimators=300, max_depth=6, random_state=0)
model_rf = regr.fit(data_train, target_train)
target_pred_rf = model_rf.predict(data_test)

# %%
" using Ada Boost regressor as black box: "
adaBoostRegr = AdaBoostRegressor(random_state=0, n_estimators=500)
model_abr = adaBoostRegr.fit(data_train, target_train)
target_pred_abr = model_abr.predict(data_test)

# %%
" using Sklearn MLP regressor as black box: "

mlp = make_pipeline(StandardScaler(),
                    MLPRegressor(hidden_layer_sizes=(100, 100),
                                 tol=1e-2, 
                                 max_iter=1000, 
                                 random_state=0))
model_nt = mlp.fit(data_train, target_train)
target_pred_nt = model_nt.predict(data_test)

# %% [markdown]
# ## Scores of the black box models

# %%
print(f"{'The score of the linear regression model is ' :<60}{': {}'.format(round(model_reg.score(data_test, target_test),4))}")
print(f"{'The score of the Random Forest Regressor model is ':<60}{': {}'.format(round(model_rf.score(data_test, target_test),4))}")
print(f"{'The score of the AdaBoost Regressor model is ':<60}{': {}'.format(round(model_abr.score(data_test, target_test),4))}")
print(f"{'The score of the Multi-Layer-Perceptron Regressor model is ':<60}{': {}'.format(round(model_nt.score(data_test, target_test),4))}")
# Out:
# The score of the linear regression model is                 : 0.1697
# The score of the Random Forest Regressor model is           : 0.7922
# The score of the AdaBoost Regressor model is                : 0.3774
# The score of the Multi-Layer-Perceptron Regressor model is  : 0.858

# %% [markdown]
# ## Execution of Split Based Selection Form Algorithm :

# %%
split_point = len(numerical_cols)
nb_models = 100
(L_Subgroups,P) = SplitBasedSelectionForm (data_test, target_test, nb_models, model_rf, list_neigh,split_point)

# %%
'SAVE THE LIST OF THE SUBGROUPS'
save_obj(L_Subgroups, path + 'list_subgroups')

# %% [markdown]
# ## Subgroups Descriptions

# %%
att_names = data_test_df.columns
patt_descriptions = patterns(P,split_point,data_test,att_names)
# Out:
# subrgoup 0
# 49.3 < age <= 55.2
# -------------------------------------------------------------------
# subrgoup 1
# 36.0 < age <= 49.3
# sex_male = 1
# -------------------------------------------------------------------
# subrgoup 2
# 36.0 < age <= 49.3
# sex_male = 0
# -------------------------------------------------------------------
# subrgoup 3
# 75.1 < age <= 85.0
# sex_male = 0
# -------------------------------------------------------------------
# subrgoup 4
# 66.2 < age <= 70.3
# 0.52 < DFA <= 0.64
# -------------------------------------------------------------------
# subrgoup 5
# 76.2 < age <= 85.0
# sex_male = 1
# -------------------------------------------------------------------
# subrgoup 6
# 56.1 < age <= 57.8
# sex_male = 1
# -------------------------------------------------------------------
# subrgoup 7
# 73.8 < age <= 75.1
# 0.7 < DFA <= 0.82
# 107.83 < test_time <= 212.39
# -------------------------------------------------------------------
# subrgoup 8
# 73.8 < age <= 75.1
# 0.7 < DFA <= 0.82
# -4.26 < test_time <= 107.83
# -------------------------------------------------------------------
# subrgoup 9
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.02 < PPE <= 0.05
# -------------------------------------------------------------------
# subrgoup 10
# 58.1 < age <= 59.2
# 0.62 < DFA <= 0.82
# -------------------------------------------------------------------
# subrgoup 11
# 70.3 < age <= 72.0
# 0.52 < DFA <= 0.66
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 12
# 70.3 < age <= 72.0
# 0.52 < DFA <= 0.66
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 13
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.03 < Shimmer:APQ5 <= 0.14
# -------------------------------------------------------------------
# subrgoup 14
# 65.6 < age <= 67.0
# 0.64 < DFA <= 0.82
# 0.59 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 15
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 21.25 < HNR <= 34.46
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 16
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 21.25 < HNR <= 34.46
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 17
# 58.4 < age <= 62.0
# 0.52 < DFA <= 0.62
# -------------------------------------------------------------------
# subrgoup 18
# 57.8 < age <= 58.4
# 0.52 < DFA <= 0.62
# -------------------------------------------------------------------
# subrgoup 19
# 67.0 < age <= 70.3
# 0.64 < DFA <= 0.82
# 78.52 < test_time <= 212.39
# -------------------------------------------------------------------
# subrgoup 20
# 57.8 < age <= 58.1
# 0.62 < DFA <= 0.82
# 24.19 < HNR <= 34.46
# -------------------------------------------------------------------
# subrgoup 21
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# -4.26 < test_time <= 167.43
# 0.25 < RPDE <= 0.42
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 22
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# -4.26 < test_time <= 167.43
# 0.25 < RPDE <= 0.42
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 23
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# 83.43 < test_time <= 167.43
# 0.42 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 24
# 55.2 < age <= 56.1
# 0.02 < Shimmer:APQ3 <= 0.11
# -------------------------------------------------------------------
# subrgoup 25
# 74.1 < age <= 75.1
# 0.52 < DFA <= 0.7
# 0.0 < Jitter:RAP <= 0.05
# -------------------------------------------------------------------
# subrgoup 26
# 74.1 < age <= 75.1
# 0.52 < DFA <= 0.7
# 0.0 < Jitter:RAP <= 0.0
# -------------------------------------------------------------------
# subrgoup 27
# 63.6 < age <= 65.6
# 0.66 < DFA <= 0.82
# -4.26 < test_time <= 144.03
# 0.02 < PPE <= 0.09
# -------------------------------------------------------------------
# subrgoup 28
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# 83.43 < test_time <= 167.43
# 0.42 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# 0.02 < NHR <= 0.56
# -------------------------------------------------------------------
# subrgoup 29
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# 83.43 < test_time <= 167.43
# 0.42 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# 0.0 < NHR <= 0.02
# -------------------------------------------------------------------
# subrgoup 30
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.25 < RPDE <= 0.5
# 0.0 < NHR <= 0.01
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 31
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.25 < RPDE <= 0.5
# 0.0 < NHR <= 0.01
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 32
# 61.0 < age <= 62.0
# 0.62 < DFA <= 0.82
# -------------------------------------------------------------------
# subrgoup 33
# 59.2 < age <= 61.0
# 0.62 < DFA <= 0.82
# -------------------------------------------------------------------
# subrgoup 34
# 62.0 < age <= 63.6
# -4.26 < test_time <= 134.13
# 0.52 < DFA <= 0.66
# -------------------------------------------------------------------
# subrgoup 35
# 62.0 < age <= 63.6
# -4.26 < test_time <= 134.13
# 0.66 < DFA <= 0.68
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 36
# 62.0 < age <= 63.6
# -4.26 < test_time <= 134.13
# 0.66 < DFA <= 0.68
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 37
# 62.0 < age <= 63.6
# 134.13 < test_time <= 212.39
# 0.0 < Jitter(%) <= 0.08
# -------------------------------------------------------------------
# subrgoup 38
# 62.0 < age <= 63.6
# 134.13 < test_time <= 212.39
# 0.0 < Jitter(%) <= 0.0
# -------------------------------------------------------------------
# subrgoup 39
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 21.25 < HNR <= 34.46
# 0.0 < Jitter(Abs) <= 0.0
# 0.25 < RPDE <= 0.47
# -------------------------------------------------------------------
# subrgoup 40
# 67.0 < age <= 70.3
# 0.64 < DFA <= 0.82
# -4.26 < test_time <= 78.52
# sex_male = 1
# -------------------------------------------------------------------
# subrgoup 41
# 67.0 < age <= 70.3
# 0.64 < DFA <= 0.82
# -4.26 < test_time <= 78.52
# sex_male = 0
# -------------------------------------------------------------------
# subrgoup 42
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# 167.43 < test_time <= 212.39
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 43
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# 167.43 < test_time <= 212.39
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 44
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.5 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 45
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.5 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 46
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.5 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# 0.0 < NHR <= 0.01
# -------------------------------------------------------------------
# subrgoup 47
# 65.6 < age <= 67.0
# 0.78 < DFA <= 0.82
# 0.25 < RPDE <= 0.59
# -------------------------------------------------------------------
# subrgoup 48
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.25 < RPDE <= 0.5
# 0.01 < NHR <= 0.56
# 142.38 < test_time <= 212.39
# -------------------------------------------------------------------
# subrgoup 49
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.25 < RPDE <= 0.5
# 0.01 < NHR <= 0.56
# -4.26 < test_time <= 142.38
# 2.96 < HNR <= 23.33
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 50
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.25 < RPDE <= 0.5
# 0.01 < NHR <= 0.56
# -4.26 < test_time <= 142.38
# 2.96 < HNR <= 23.33
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 51
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.25 < RPDE <= 0.5
# 0.01 < NHR <= 0.56
# -4.26 < test_time <= 142.38
# 23.33 < HNR <= 34.46
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 52
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.25 < RPDE <= 0.5
# 0.01 < NHR <= 0.56
# -4.26 < test_time <= 142.38
# 23.33 < HNR <= 34.46
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 53
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.01 < Shimmer:APQ3 <= 0.03
# 0.0 < Shimmer:APQ5 <= 0.03
# -4.26 < test_time <= 83.43
# 0.42 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 54
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.0 < Shimmer:APQ3 <= 0.01
# 0.0 < Shimmer:APQ5 <= 0.03
# -4.26 < test_time <= 83.43
# 0.42 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 55
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.03 < Shimmer:APQ3 <= 0.11
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 56
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 2.96 < HNR <= 21.25
# 0.03 < Shimmer:APQ3 <= 0.11
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 57
# 73.8 < age <= 74.1
# 0.52 < DFA <= 0.7
# 0.0 < Jitter(Abs) <= 0.0
# 0.64 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 58
# 73.8 < age <= 74.1
# 0.52 < DFA <= 0.7
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 59
# 73.8 < age <= 74.1
# 0.52 < DFA <= 0.7
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 60
# 65.6 < age <= 66.2
# 0.52 < DFA <= 0.64
# 26.25 < HNR <= 34.46
# -------------------------------------------------------------------
# subrgoup 61
# 65.6 < age <= 66.2
# 0.52 < DFA <= 0.64
# 2.96 < HNR <= 26.25
# -------------------------------------------------------------------
# subrgoup 62
# 63.6 < age <= 65.6
# 0.66 < DFA <= 0.68
# -4.26 < test_time <= 144.03
# 0.09 < PPE <= 0.59
# 0.39 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 63
# 63.6 < age <= 65.6
# 0.66 < DFA <= 0.68
# -4.26 < test_time <= 144.03
# 0.09 < PPE <= 0.59
# 0.25 < RPDE <= 0.39
# -------------------------------------------------------------------
# subrgoup 64
# 65.6 < age <= 67.0
# 0.68 < DFA <= 0.78
# 0.25 < RPDE <= 0.59
# -------------------------------------------------------------------
# subrgoup 65
# 65.6 < age <= 67.0
# 0.64 < DFA <= 0.68
# 0.25 < RPDE <= 0.59
# -------------------------------------------------------------------
# subrgoup 66
# 63.6 < age <= 65.6
# 0.68 < DFA <= 0.82
# 16.63 < test_time <= 144.03
# 0.09 < PPE <= 0.59
# 0.01 < Shimmer:APQ3 <= 0.11
# -------------------------------------------------------------------
# subrgoup 67
# 63.6 < age <= 65.6
# 0.68 < DFA <= 0.82
# 16.63 < test_time <= 144.03
# 0.09 < PPE <= 0.59
# 0.0 < Shimmer:APQ3 <= 0.01
# -------------------------------------------------------------------
# subrgoup 68
# 57.8 < age <= 58.1
# 0.62 < DFA <= 0.82
# 2.96 < HNR <= 24.19
# 0.01 < Shimmer:APQ5 <= 0.14
# -------------------------------------------------------------------
# subrgoup 69
# 57.8 < age <= 58.1
# 0.62 < DFA <= 0.82
# 2.96 < HNR <= 24.19
# 0.0 < Shimmer:APQ5 <= 0.01
# -------------------------------------------------------------------
# subrgoup 70
# 72.0 < age <= 73.8
# 0.58 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 71
# 72.0 < age <= 73.8
# 0.52 < RPDE <= 0.58
# -------------------------------------------------------------------
# subrgoup 72
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 21.25 < HNR <= 34.46
# 0.0 < Jitter(Abs) <= 0.0
# 0.47 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 73
# 70.3 < age <= 72.0
# 0.66 < DFA <= 0.82
# 21.25 < HNR <= 34.46
# 0.0 < Jitter(Abs) <= 0.0
# 0.47 < RPDE <= 0.81
# -------------------------------------------------------------------
# subrgoup 74
# 62.0 < age <= 63.6
# -4.26 < test_time <= 134.13
# 0.68 < DFA <= 0.82
# 0.03 < Shimmer:APQ3 <= 0.11
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 75
# 62.0 < age <= 63.6
# -4.26 < test_time <= 134.13
# 0.68 < DFA <= 0.82
# 0.03 < Shimmer:APQ3 <= 0.11
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 76
# 62.0 < age <= 63.6
# -4.26 < test_time <= 134.13
# 0.68 < DFA <= 0.82
# 0.02 < Shimmer:APQ3 <= 0.03
# -------------------------------------------------------------------
# subrgoup 77
# 62.0 < age <= 63.6
# -4.26 < test_time <= 134.13
# 0.68 < DFA <= 0.82
# 0.0 < Shimmer:APQ3 <= 0.02
# -------------------------------------------------------------------
# subrgoup 78
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.5 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# 0.01 < NHR <= 0.56
# -------------------------------------------------------------------
# subrgoup 79
# 63.6 < age <= 65.6
# 0.52 < DFA <= 0.66
# 0.05 < PPE <= 0.59
# 0.5 < RPDE <= 0.81
# 0.0 < Jitter(Abs) <= 0.0
# 0.01 < NHR <= 0.56
# -------------------------------------------------------------------
# subrgoup 80
# 75.1 < age <= 76.2
# sex_male = 1
# 0.02 < Shimmer:APQ5 <= 0.14
# -------------------------------------------------------------------
# subrgoup 81
# 75.1 < age <= 76.2
# sex_male = 1
# 0.01 < Shimmer:APQ5 <= 0.02
# -------------------------------------------------------------------
# subrgoup 82
# 75.1 < age <= 76.2
# sex_male = 1
# 0.0 < Shimmer:APQ5 <= 0.01
# -------------------------------------------------------------------
# subrgoup 83
# 72.0 < age <= 73.8
# 0.25 < RPDE <= 0.52
# 24.08 < HNR <= 34.46
# -------------------------------------------------------------------
# subrgoup 84
# 72.0 < age <= 73.8
# 0.25 < RPDE <= 0.52
# 2.96 < HNR <= 24.08
# -------------------------------------------------------------------
# subrgoup 85
# 55.2 < age <= 56.1
# 0.0 < Shimmer:APQ3 <= 0.02
# 0.0 < Jitter:PPQ5 <= 0.06
# -------------------------------------------------------------------
# subrgoup 86
# 55.2 < age <= 56.1
# 0.0 < Shimmer:APQ3 <= 0.02
# 0.0 < Jitter:PPQ5 <= 0.0
# 152.69 < test_time <= 212.39
# -------------------------------------------------------------------
# subrgoup 87
# 55.2 < age <= 56.1
# 0.0 < Shimmer:APQ3 <= 0.02
# 0.0 < Jitter:PPQ5 <= 0.0
# -4.26 < test_time <= 152.69
# -------------------------------------------------------------------
# subrgoup 88
# 73.8 < age <= 74.1
# 0.52 < DFA <= 0.7
# 0.0 < Jitter(Abs) <= 0.0
# 0.25 < RPDE <= 0.64
# -------------------------------------------------------------------
# subrgoup 89
# 73.8 < age <= 74.1
# 0.52 < DFA <= 0.7
# 0.0 < Jitter(Abs) <= 0.0
# 0.25 < RPDE <= 0.64
# -------------------------------------------------------------------
# subrgoup 90
# 56.1 < age <= 57.8
# sex_male = 0
# 0.02 < Shimmer:APQ3 <= 0.11
# -------------------------------------------------------------------
# subrgoup 91
# 56.1 < age <= 57.8
# sex_male = 0
# 0.0 < Shimmer:APQ3 <= 0.02
# 0.52 < DFA <= 0.65
# -------------------------------------------------------------------
# subrgoup 92
# 56.1 < age <= 57.8
# sex_male = 0
# 0.0 < Shimmer:APQ3 <= 0.01
# 0.65 < DFA <= 0.82
# -------------------------------------------------------------------
# subrgoup 93
# 56.1 < age <= 57.8
# sex_male = 0
# 0.01 < Shimmer:APQ3 <= 0.02
# 0.65 < DFA <= 0.82
# 0.02 < Shimmer:APQ5 <= 0.14
# -------------------------------------------------------------------
# subrgoup 94
# 56.1 < age <= 57.8
# sex_male = 0
# 0.01 < Shimmer:APQ3 <= 0.02
# 0.65 < DFA <= 0.82
# 0.0 < Shimmer:APQ5 <= 0.02
# 0.01 < NHR <= 0.56
# -------------------------------------------------------------------
# subrgoup 95
# 56.1 < age <= 57.8
# sex_male = 0
# 0.01 < Shimmer:APQ3 <= 0.02
# 0.65 < DFA <= 0.82
# 0.0 < Shimmer:APQ5 <= 0.02
# 0.0 < NHR <= 0.01
# -------------------------------------------------------------------
# subrgoup 96
# 63.6 < age <= 65.6
# 0.66 < DFA <= 0.82
# 144.03 < test_time <= 212.39
# 0.03 < NHR <= 0.56
# -------------------------------------------------------------------
# subrgoup 97
# 63.6 < age <= 65.6
# 0.66 < DFA <= 0.82
# 144.03 < test_time <= 212.39
# 0.0 < NHR <= 0.03
# -------------------------------------------------------------------
# subrgoup 98
# 63.6 < age <= 65.6
# 0.68 < DFA <= 0.82
# -4.26 < test_time <= 16.63
# 0.09 < PPE <= 0.59
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------
# subrgoup 99
# 63.6 < age <= 65.6
# 0.68 < DFA <= 0.82
# -4.26 < test_time <= 16.63
# 0.09 < PPE <= 0.59
# 0.0 < Jitter(Abs) <= 0.0
# -------------------------------------------------------------------

# %%
'SAVE THE SUBGROUPS PATTERNS'
save_obj(patt_descriptions, path + 'patterns')
save_obj(att_names, path + 'att_names')
